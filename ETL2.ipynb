# %% [markdown]
# # ETL 2 Proyecto Individual ML Ops STEAM,

# %% [markdown]
# ## Refinamiento de los Data Sets para las funciones

# %% [markdown]
# ---

# %%
# Se importan las librerías necesarias para este proceso de transformación
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Rutas de ubicación para los datasets:
ruta_reviews = 'E:\\AAADATOS\Henry\\AA_Data_Science\\MATERIAL_PI\\PI_ML_OPS_STEAM_DSFT17\\user_reviews.csv'
ruta_items = 'E:\\AAADATOS\Henry\\AA_Data_Science\\MATERIAL_PI\\PI_ML_OPS_STEAM_DSFT17\\user_items.csv'
ruta_games = 'E:\\AAADATOS\Henry\\AA_Data_Science\\MATERIAL_PI\\PI_ML_OPS_STEAM_DSFT17\\user_games.csv'

# %%
# Se inicializan los Data Sets 
df_reviews = pd.read_csv(ruta_reviews)
df_items = pd.read_csv(ruta_items)
df_games = pd.read_csv(ruta_games)

# %% [markdown]
# Se visualizan los Data Frames

# %%
df_reviews.head()
# Out:
#              User_Id  Item_Id  Recommend  Year        Date  Sentiment_Analysis
# 0  76561197970982479     1250       True  2011  2011-11-05                   2
# 1  76561197970982479    22200       True  2011  2011-07-15                   2
# 2  76561197970982479    43110       True  2011  2011-04-21                   2
# 3            js41637   251610       True  2014  2014-06-24                   2
# 4            js41637   227300       True  2013  2013-09-08                   2

# %%
df_items.head()
# Out:
#              User_Id  Items_Count           Steam_Id  Item_Id  \
# 0  76561197970982479          277  76561197970982479       10
# 1  76561197970982479          277  76561197970982479       30
# 2  76561197970982479          277  76561197970982479      300
# 3  76561197970982479          277  76561197970982479      240
# 4  76561197970982479          277  76561197970982479     3830
#
#                 Item_Name  Playtime_Forever_Hours
# 0          Counter-Strike                       1
# 1           Day of Defeat                       1
# 2   Day of Defeat: Source                      79
# 3  Counter-Strike: Source                      31
# 4             Psychonauts                       6

# %%
df_games.head()
# Out:
#    Item_Id                    Title  Year            Publisher  \
# 0   761140      Lost Summoner Kitty  2018            Kotoshiro
# 1   643980                Ironbound  2018     Making Fun, Inc.
# 2   670290  Real Pool 3D - Poolians  2017         Poolians.com
# 3   767400                  弹炸人2222  2017                 彼岸领域
# 4   772540    Battle Royale Trainer  2018  Trickjump Games Ltd
#
#              Developer                                             Genres
# 0            Kotoshiro        Simulation, Casual, Strategy, Action, Indie
# 1     Making Fun, Inc.  2D, Design & Illustration, RPG, Trading Card G...
# 2         Poolians.com  Sports, Free to Play, Simulation, Casual, Mult...
# 3                 彼岸领域                          Adventure, Action, Casual
# 4  Trickjump Games Ltd  Sniper, Shooter, Third Person, Simulation, Thi...

# %%
print(f'El tamaño del Data Frame Reviews es de {df_reviews.shape}')
print(f'El tamaño del Data Frame Items es de {df_items.shape}')
print(f'El tamaño del Data Frame Games es de {df_games.shape}')
# Out:
# El tamaño del Data Frame Reviews es de (59305, 6)
# El tamaño del Data Frame Items es de (3285246, 6)
# El tamaño del Data Frame Games es de (28663, 6)

# %% [markdown]
# ---

# %% [markdown]
# ### Nuevo proceso de limpieza

# %% [markdown]
# Gracias al proceso anterior del **`“EDA`** se pudieron identificar unos valores en el Data Set **`“Games”`** que se perfilaron para ser eliminados.

# %%
# Se crea un Data Frame filtrado 
no_developer = df_games[df_games['Developer'] == '(none)']
no_developer
# Out:
#        Item_Id           Title  Year Publisher Developer  \
# 3705    253250     Stonehearth  2015    (none)    (none)
# 16224   548130  Scribble Ships  2017    (none)    (none)
#
#                                                   Genres
# 3705   RTS, Multiplayer, Building, RPG, Cute, Open Wo...
# 16224                              Arcade, Action, Indie

# %%
# Se hace un merge para eliminar las filas del Data Frame filtrado del Data Frame original
df_games = pd.merge(df_games, no_developer, on='Item_Id', how='left', indicator=True).query('_merge == "left_only"').drop('_merge', axis=1)
df_games.shape # Se comprueba que el tamaño del Data Frame haya cambiado
# Out:
# (28661, 11)

# %%
df_games = df_games.drop(columns=['Title_y', 'Year_y', 'Publisher_y', 'Developer_y', 'Genres_y']) # Se eliminan columnas residuales del proceso anterior

# %%
# Se normalizan nuevamente los nombres de las columnas del Data Frame
df_games = df_games.rename(columns={'Title_x': 'Title'})
df_games = df_games.rename(columns={'Year_x': 'Year_Launch'})
df_games = df_games.rename(columns={'Publisher_x': 'Publisher'})
df_games = df_games.rename(columns={'Developer_x': 'Developer'})
df_games = df_games.rename(columns={'Genres_x': 'Genres'})

# %%
df_games
# Out:
#        Item_Id                     Title  Year_Launch            Publisher  \
# 0       761140       Lost Summoner Kitty         2018            Kotoshiro
# 1       643980                 Ironbound         2018     Making Fun, Inc.
# 2       670290   Real Pool 3D - Poolians         2017         Poolians.com
# 3       767400                   弹炸人2222         2017                 彼岸领域
# 4       772540     Battle Royale Trainer         2018  Trickjump Games Ltd
# ...        ...                       ...          ...                  ...
# 28658   745400              Kebab it Up!         2018      Bidoniera Games
# 28659   773640            Colony On Mars         2018      Ghost_RUS Games
# 28660   733530  LOGistICAL: South Africa         2018               Sacada
# 28661   610660             Russian Roads         2018         Laush Studio
# 28662   658870       EXIT 2 - Directions         2017             SIXNAILS
#
#                  Developer                                             Genres
# 0                Kotoshiro        Simulation, Casual, Strategy, Action, Indie
# 1         Making Fun, Inc.  2D, Design & Illustration, RPG, Trading Card G...
# 2             Poolians.com  Sports, Free to Play, Simulation, Casual, Mult...
# 3                     彼岸领域                          Adventure, Action, Casual
# 4      Trickjump Games Ltd  Sniper, Shooter, Third Person, Simulation, Thi...
# ...                    ...                                                ...
# 28658      Bidoniera Games          Violent, Casual, Adventure, Action, Indie
# 28659      Ghost_RUS Games                Strategy, Simulation, Casual, Indie
# 28660               Sacada                            Strategy, Casual, Indie
# 28661         Laush Studio                          Simulation, Racing, Indie
# 28662             SIXNAILS  Relaxing, Casual, Singleplayer, Puzzle, Indie,...
#
# [28661 rows x 6 columns]

# %% [markdown]
# Se procede a eliminar los géneros con menos frecuencias del campo **`"Genres"`**

# %%
# Se crea la lista con dichos géneros
menos_frec = ['Real-Time with Pause', 'Dystopian', 'Audio Production', 'Loot', 'Arena Shooter', '2.5D', 'Rhythm', 'Experimental', 'Clicker', 'Cartoon',
              'Pirates', 'Mechs', 'Wargame', 'Otome', 'Space Sim', 'Hex Grid', 'MOBA', 'GameMaker', 'Real-Time', 'Crime', 'Episodic', 'Noir', 'Photo Editing',
              'Naval', 'Trading Card Game', 'VR', 'Ninja', 'Mod', 'Tanks', 'Split Screen', 'Tactical RPG', 'Mouse only', 'Voxel', 'Strategy RPG', '1980s',
              'Psychological', 'Dragons', 'Runner', '3D Vision', 'Western', 'CRPG', 'Alternate History', 'Dinosaurs', 'Blood', 'Real Time Tactics', 'Linear',
              'Score Attack', 'Hacking', 'Superhero', 'Demons', 'Science', 'FMV', 'Cold War', 'Comic Book', 'Parody', 'Drama', 'Time Travel', 'Underwater',
              'Psychedelic', 'Swordplay', 'e-sports', 'Politics', 'Football', 'PvE', 'Narration', 'Trading', 'God Game', 'Political', 'Games Workshop',
              'Villain Protagonist', 'Vampire', 'Assassin', 'Heist', 'Hunting', 'Programming', 'Gothic', 'Mythology', 'World War I', 'LEGO', 'Soccer',
              'Rome', 'Satire', 'Cinematic', 'Crowdfunded', 'Grid-Based Movement', 'Character Action Game', 'Agriculture', 'Class-Based', 'Supernatural',
              'Warhammer 40K', 'Silent Protagonist', 'Quick-Time Events', 'Asynchronous Multiplayer', 'Lore-Rich', 'Bullet Time', 'Time Attack', 'Pinball',
              'Time Manipulation', 'Typing', 'America', 'Based On A Novel', 'Dark Comedy', 'Chess', '6DOF', 'Star Wars', 'Conspiracy', 'Sailing',
              'Spectacle fighter', 'Offroad', 'On-Rails Shooter', 'Batman', 'Co-op Campaign', 'Thriller', 'Fishing', '', 'Martial Arts', 'Modern',
              'Capitalism', 'Mars', 'Diplomacy', 'Sniper', 'Philisophical', 'Gun Customization', 'Music-Based Procedural Generation', 'Sokoban', 'Horses',
              'Movie', 'Nonlinear', 'Word Game', 'Werewolves', 'Mining', 'Golf', 'Benchmark', 'Gambling', 'Inventory Management', 'Gaming', 'Lemmings',
              'Lara Croft', 'Mystery Dungeon', 'Experience', 'Dynamic Narration', 'Basketball', 'Mini Golf', 'Documentary', 'Investigation', 'Conversation',
              'Wrestling', 'Artificial Intelligence', 'Spelling', 'Pool', 'Steam Machine', 'Intentionally Awkward Controls', 'Underground', 'NSFW',
              'Transhumanism', 'Bowling', 'Tutorial', 'Cycling', 'Voice Control', 'Faith', 'Accounting', 'Hardware', 'Foreign']

# %%
# Se convierte la lista a un patrón de expresión regular
patron_regex = '|'.join(menos_frec)

# %%
# Se itera con un ciclo ‘for’ para comprobar que los géneros se eliminen  
for palabra in menos_frec:
    if df_games['Genres'].str.contains(palabra).any():
        print(f'La palabra "{palabra}" todavía está presente en alguna fila.')
    else:
        print(f'La palabra "{palabra}" no está presente en ninguna fila.')
# Out:
# La palabra "Real-Time with Pause" todavía está presente en alguna fila.
# La palabra "Dystopian" todavía está presente en alguna fila.
# La palabra "Audio Production" todavía está presente en alguna fila.
# La palabra "Loot" todavía está presente en alguna fila.
# La palabra "Arena Shooter" todavía está presente en alguna fila.
# La palabra "2.5D" todavía está presente en alguna fila.
# La palabra "Rhythm" todavía está presente en alguna fila.
# La palabra "Experimental" todavía está presente en alguna fila.
# La palabra "Clicker" todavía está presente en alguna fila.
# La palabra "Cartoon" todavía está presente en alguna fila.
# La palabra "Pirates" todavía está presente en alguna fila.
# La palabra "Mechs" todavía está presente en alguna fila.
# La palabra "Wargame" todavía está presente en alguna fila.
# La palabra "Otome" todavía está presente en alguna fila.
# La palabra "Space Sim" todavía está presente en alguna fila.
# La palabra "Hex Grid" todavía está presente en alguna fila.
# La palabra "MOBA" todavía está presente en alguna fila.
# La palabra "GameMaker" todavía está presente en alguna fila.
# La palabra "Real-Time" todavía está presente en alguna fila.
# La palabra "Crime" todavía está presente en alguna fila.
# La palabra "Episodic" todavía está presente en alguna fila.
# La palabra "Noir" todavía está presente en alguna fila.
# La palabra "Photo Editing" todavía está presente en alguna fila.
# La palabra "Naval" todavía está presente en alguna fila.
# La palabra "Trading Card Game" todavía está presente en alguna fila.
# La palabra "VR" todavía está presente en alguna fila.
# La palabra "Ninja" todavía está presente en alguna fila.
# La palabra "Mod" todavía está presente en alguna fila.
# La palabra "Tanks" todavía está presente en alguna fila.
# La palabra "Split Screen" todavía está presente en alguna fila.
# La palabra "Tactical RPG" todavía está presente en alguna fila.
# La palabra "Mouse only" todavía está presente en alguna fila.
# La palabra "Voxel" todavía está presente en alguna fila.
# La palabra "Strategy RPG" todavía está presente en alguna fila.
# La palabra "1980s" todavía está presente en alguna fila.
# La palabra "Psychological" todavía está presente en alguna fila.
# La palabra "Dragons" todavía está presente en alguna fila.
# La palabra "Runner" todavía está presente en alguna fila.
# La palabra "3D Vision" todavía está presente en alguna fila.
# La palabra "Western" todavía está presente en alguna fila.
# La palabra "CRPG" todavía está presente en alguna fila.
# La palabra "Alternate History" todavía está presente en alguna fila.
# La palabra "Dinosaurs" todavía está presente en alguna fila.
# La palabra "Blood" todavía está presente en alguna fila.
# La palabra "Real Time Tactics" todavía está presente en alguna fila.
# La palabra "Linear" todavía está presente en alguna fila.
# La palabra "Score Attack" todavía está presente en alguna fila.
# La palabra "Hacking" todavía está presente en alguna fila.
# La palabra "Superhero" todavía está presente en alguna fila.
# La palabra "Demons" todavía está presente en alguna fila.
# La palabra "Science" todavía está presente en alguna fila.
# La palabra "FMV" todavía está presente en alguna fila.
# La palabra "Cold War" todavía está presente en alguna fila.
# La palabra "Comic Book" todavía está presente en alguna fila.
# La palabra "Parody" todavía está presente en alguna fila.
# La palabra "Drama" todavía está presente en alguna fila.
# La palabra "Time Travel" todavía está presente en alguna fila.
# La palabra "Underwater" todavía está presente en alguna fila.
# La palabra "Psychedelic" todavía está presente en alguna fila.
# La palabra "Swordplay" todavía está presente en alguna fila.
# La palabra "e-sports" todavía está presente en alguna fila.
# La palabra "Politics" todavía está presente en alguna fila.
# La palabra "Football" todavía está presente en alguna fila.
# La palabra "PvE" todavía está presente en alguna fila.
# La palabra "Narration" todavía está presente en alguna fila.
# La palabra "Trading" todavía está presente en alguna fila.
# La palabra "God Game" todavía está presente en alguna fila.
# La palabra "Political" todavía está presente en alguna fila.
# La palabra "Games Workshop" todavía está presente en alguna fila.
# La palabra "Villain Protagonist" todavía está presente en alguna fila.
# La palabra "Vampire" todavía está presente en alguna fila.
# La palabra "Assassin" todavía está presente en alguna fila.
# La palabra "Heist" todavía está presente en alguna fila.
# La palabra "Hunting" todavía está presente en alguna fila.
# La palabra "Programming" todavía está presente en alguna fila.
# La palabra "Gothic" todavía está presente en alguna fila.
# La palabra "Mythology" todavía está presente en alguna fila.
# La palabra "World War I" todavía está presente en alguna fila.
# La palabra "LEGO" todavía está presente en alguna fila.
# La palabra "Soccer" todavía está presente en alguna fila.
# La palabra "Rome" todavía está presente en alguna fila.
# La palabra "Satire" todavía está presente en alguna fila.
# La palabra "Cinematic" todavía está presente en alguna fila.
# La palabra "Crowdfunded" todavía está presente en alguna fila.
# La palabra "Grid-Based Movement" todavía está presente en alguna fila.
# La palabra "Character Action Game" todavía está presente en alguna fila.
# La palabra "Agriculture" todavía está presente en alguna fila.
# La palabra "Class-Based" todavía está presente en alguna fila.
# La palabra "Supernatural" todavía está presente en alguna fila.
# La palabra "Warhammer 40K" todavía está presente en alguna fila.
# La palabra "Silent Protagonist" todavía está presente en alguna fila.
# La palabra "Quick-Time Events" todavía está presente en alguna fila.
# La palabra "Asynchronous Multiplayer" todavía está presente en alguna fila.
# La palabra "Lore-Rich" todavía está presente en alguna fila.
# La palabra "Bullet Time" todavía está presente en alguna fila.
# La palabra "Time Attack" todavía está presente en alguna fila.
# La palabra "Pinball" todavía está presente en alguna fila.
# La palabra "Time Manipulation" todavía está presente en alguna fila.
# La palabra "Typing" todavía está presente en alguna fila.
# La palabra "America" todavía está presente en alguna fila.
# La palabra "Based On A Novel" todavía está presente en alguna fila.
# La palabra "Dark Comedy" todavía está presente en alguna fila.
# La palabra "Chess" todavía está presente en alguna fila.
# La palabra "6DOF" todavía está presente en alguna fila.
# La palabra "Star Wars" todavía está presente en alguna fila.
# La palabra "Conspiracy" todavía está presente en alguna fila.
# La palabra "Sailing" todavía está presente en alguna fila.
# La palabra "Spectacle fighter" todavía está presente en alguna fila.
# La palabra "Offroad" todavía está presente en alguna fila.
# La palabra "On-Rails Shooter" todavía está presente en alguna fila.
# La palabra "Batman" todavía está presente en alguna fila.
# La palabra "Co-op Campaign" todavía está presente en alguna fila.
# La palabra "Thriller" todavía está presente en alguna fila.
# La palabra "Fishing" todavía está presente en alguna fila.
# La palabra "" todavía está presente en alguna fila.
# La palabra "Martial Arts" todavía está presente en alguna fila.
# La palabra "Modern" todavía está presente en alguna fila.
# La palabra "Capitalism" todavía está presente en alguna fila.
# La palabra "Mars" todavía está presente en alguna fila.
# La palabra "Diplomacy" todavía está presente en alguna fila.
# La palabra "Sniper" todavía está presente en alguna fila.
# La palabra "Philisophical" todavía está presente en alguna fila.
# La palabra "Gun Customization" todavía está presente en alguna fila.
# La palabra "Music-Based Procedural Generation" todavía está presente en alguna fila.
# La palabra "Sokoban" todavía está presente en alguna fila.
# La palabra "Horses" todavía está presente en alguna fila.
# La palabra "Movie" todavía está presente en alguna fila.
# La palabra "Nonlinear" todavía está presente en alguna fila.
# La palabra "Word Game" todavía está presente en alguna fila.
# La palabra "Werewolves" todavía está presente en alguna fila.
# La palabra "Mining" todavía está presente en alguna fila.
# La palabra "Golf" todavía está presente en alguna fila.
# La palabra "Benchmark" todavía está presente en alguna fila.
# La palabra "Gambling" todavía está presente en alguna fila.
# La palabra "Inventory Management" todavía está presente en alguna fila.
# La palabra "Gaming" todavía está presente en alguna fila.
# La palabra "Lemmings" todavía está presente en alguna fila.
# La palabra "Lara Croft" todavía está presente en alguna fila.
# La palabra "Mystery Dungeon" todavía está presente en alguna fila.
# La palabra "Experience" todavía está presente en alguna fila.
# La palabra "Dynamic Narration" todavía está presente en alguna fila.
# La palabra "Basketball" todavía está presente en alguna fila.
# La palabra "Mini Golf" todavía está presente en alguna fila.
# La palabra "Documentary" todavía está presente en alguna fila.
# La palabra "Investigation" todavía está presente en alguna fila.
# La palabra "Conversation" todavía está presente en alguna fila.
# La palabra "Wrestling" todavía está presente en alguna fila.
# La palabra "Artificial Intelligence" todavía está presente en alguna fila.
# La palabra "Spelling" todavía está presente en alguna fila.
# La palabra "Pool" todavía está presente en alguna fila.
# La palabra "Steam Machine" todavía está presente en alguna fila.
# La palabra "Intentionally Awkward Controls" todavía está presente en alguna fila.
# La palabra "Underground" todavía está presente en alguna fila.
# La palabra "NSFW" todavía está presente en alguna fila.
# La palabra "Transhumanism" todavía está presente en alguna fila.
# La palabra "Bowling" todavía está presente en alguna fila.
# La palabra "Tutorial" todavía está presente en alguna fila.
# La palabra "Cycling" todavía está presente en alguna fila.
# La palabra "Voice Control" todavía está presente en alguna fila.
# La palabra "Faith" todavía está presente en alguna fila.
# La palabra "Accounting" todavía está presente en alguna fila.
# La palabra "Hardware" todavía está presente en alguna fila.
# La palabra "Foreign" todavía está presente en alguna fila.

# %%
# Se aplica la eliminación de las palbras en la columna 'Genres'
df_games['Genres'] = df_games['Genres'].str.replace(patron_regex, '', regex=True)

# %%
# Se itera nuevamente para comprobar que los géneros se hayan eliminado
for palabra in menos_frec:
    if df_games['Genres'].str.contains(palabra).any():
        print(f'La palabra "{palabra}" todavía está presente en alguna fila.')
    else:
        print(f'La palabra "{palabra}" no está presente en ninguna fila.')
# Out:
# La palabra "Real-Time with Pause" no está presente en ninguna fila.
# La palabra "Dystopian" no está presente en ninguna fila.
# La palabra "Audio Production" no está presente en ninguna fila.
# La palabra "Loot" no está presente en ninguna fila.
# La palabra "Arena Shooter" no está presente en ninguna fila.
# La palabra "2.5D" no está presente en ninguna fila.
# La palabra "Rhythm" no está presente en ninguna fila.
# La palabra "Experimental" no está presente en ninguna fila.
# La palabra "Clicker" no está presente en ninguna fila.
# La palabra "Cartoon" no está presente en ninguna fila.
# La palabra "Pirates" no está presente en ninguna fila.
# La palabra "Mechs" no está presente en ninguna fila.
# La palabra "Wargame" no está presente en ninguna fila.
# La palabra "Otome" no está presente en ninguna fila.
# La palabra "Space Sim" no está presente en ninguna fila.
# La palabra "Hex Grid" no está presente en ninguna fila.
# La palabra "MOBA" no está presente en ninguna fila.
# La palabra "GameMaker" no está presente en ninguna fila.
# La palabra "Real-Time" no está presente en ninguna fila.
# La palabra "Crime" no está presente en ninguna fila.
# La palabra "Episodic" no está presente en ninguna fila.
# La palabra "Noir" no está presente en ninguna fila.
# La palabra "Photo Editing" no está presente en ninguna fila.
# La palabra "Naval" no está presente en ninguna fila.
# La palabra "Trading Card Game" no está presente en ninguna fila.
# La palabra "VR" no está presente en ninguna fila.
# La palabra "Ninja" no está presente en ninguna fila.
# La palabra "Mod" no está presente en ninguna fila.
# La palabra "Tanks" no está presente en ninguna fila.
# La palabra "Split Screen" no está presente en ninguna fila.
# La palabra "Tactical RPG" no está presente en ninguna fila.
# La palabra "Mouse only" no está presente en ninguna fila.
# La palabra "Voxel" no está presente en ninguna fila.
# La palabra "Strategy RPG" no está presente en ninguna fila.
# La palabra "1980s" no está presente en ninguna fila.
# La palabra "Psychological" no está presente en ninguna fila.
# La palabra "Dragons" no está presente en ninguna fila.
# La palabra "Runner" no está presente en ninguna fila.
# La palabra "3D Vision" no está presente en ninguna fila.
# La palabra "Western" no está presente en ninguna fila.
# La palabra "CRPG" no está presente en ninguna fila.
# La palabra "Alternate History" no está presente en ninguna fila.
# La palabra "Dinosaurs" no está presente en ninguna fila.
# La palabra "Blood" no está presente en ninguna fila.
# La palabra "Real Time Tactics" no está presente en ninguna fila.
# La palabra "Linear" no está presente en ninguna fila.
# La palabra "Score Attack" no está presente en ninguna fila.
# La palabra "Hacking" no está presente en ninguna fila.
# La palabra "Superhero" no está presente en ninguna fila.
# La palabra "Demons" no está presente en ninguna fila.
# La palabra "Science" no está presente en ninguna fila.
# La palabra "FMV" no está presente en ninguna fila.
# La palabra "Cold War" no está presente en ninguna fila.
# La palabra "Comic Book" no está presente en ninguna fila.
# La palabra "Parody" no está presente en ninguna fila.
# La palabra "Drama" no está presente en ninguna fila.
# La palabra "Time Travel" no está presente en ninguna fila.
# La palabra "Underwater" no está presente en ninguna fila.
# La palabra "Psychedelic" no está presente en ninguna fila.
# La palabra "Swordplay" no está presente en ninguna fila.
# La palabra "e-sports" no está presente en ninguna fila.
# La palabra "Politics" no está presente en ninguna fila.
# La palabra "Football" no está presente en ninguna fila.
# La palabra "PvE" no está presente en ninguna fila.
# La palabra "Narration" no está presente en ninguna fila.
# La palabra "Trading" no está presente en ninguna fila.
# La palabra "God Game" no está presente en ninguna fila.
# La palabra "Political" no está presente en ninguna fila.
# La palabra "Games Workshop" no está presente en ninguna fila.
# La palabra "Villain Protagonist" no está presente en ninguna fila.
# La palabra "Vampire" no está presente en ninguna fila.
# La palabra "Assassin" no está presente en ninguna fila.
# La palabra "Heist" no está presente en ninguna fila.
# La palabra "Hunting" no está presente en ninguna fila.
# La palabra "Programming" no está presente en ninguna fila.
# La palabra "Gothic" no está presente en ninguna fila.
# La palabra "Mythology" no está presente en ninguna fila.
# La palabra "World War I" no está presente en ninguna fila.
# La palabra "LEGO" no está presente en ninguna fila.
# La palabra "Soccer" no está presente en ninguna fila.
# La palabra "Rome" no está presente en ninguna fila.
# La palabra "Satire" no está presente en ninguna fila.
# La palabra "Cinematic" no está presente en ninguna fila.
# La palabra "Crowdfunded" no está presente en ninguna fila.
# La palabra "Grid-Based Movement" no está presente en ninguna fila.
# La palabra "Character Action Game" no está presente en ninguna fila.
# La palabra "Agriculture" no está presente en ninguna fila.
# La palabra "Class-Based" no está presente en ninguna fila.
# La palabra "Supernatural" no está presente en ninguna fila.
# La palabra "Warhammer 40K" no está presente en ninguna fila.
# La palabra "Silent Protagonist" no está presente en ninguna fila.
# La palabra "Quick-Time Events" no está presente en ninguna fila.
# La palabra "Asynchronous Multiplayer" no está presente en ninguna fila.
# La palabra "Lore-Rich" no está presente en ninguna fila.
# La palabra "Bullet Time" no está presente en ninguna fila.
# La palabra "Time Attack" no está presente en ninguna fila.
# La palabra "Pinball" no está presente en ninguna fila.
# La palabra "Time Manipulation" no está presente en ninguna fila.
# La palabra "Typing" no está presente en ninguna fila.
# La palabra "America" no está presente en ninguna fila.
# La palabra "Based On A Novel" no está presente en ninguna fila.
# La palabra "Dark Comedy" no está presente en ninguna fila.
# La palabra "Chess" no está presente en ninguna fila.
# La palabra "6DOF" no está presente en ninguna fila.
# La palabra "Star Wars" no está presente en ninguna fila.
# La palabra "Conspiracy" no está presente en ninguna fila.
# La palabra "Sailing" no está presente en ninguna fila.
# La palabra "Spectacle fighter" no está presente en ninguna fila.
# La palabra "Offroad" no está presente en ninguna fila.
# La palabra "On-Rails Shooter" no está presente en ninguna fila.
# La palabra "Batman" no está presente en ninguna fila.
# La palabra "Co-op Campaign" no está presente en ninguna fila.
# La palabra "Thriller" no está presente en ninguna fila.
# La palabra "Fishing" no está presente en ninguna fila.
# La palabra "" todavía está presente en alguna fila.
# La palabra "Martial Arts" no está presente en ninguna fila.
# La palabra "Modern" no está presente en ninguna fila.
# La palabra "Capitalism" no está presente en ninguna fila.
# La palabra "Mars" no está presente en ninguna fila.
# La palabra "Diplomacy" no está presente en ninguna fila.
# La palabra "Sniper" no está presente en ninguna fila.
# La palabra "Philisophical" no está presente en ninguna fila.
# La palabra "Gun Customization" no está presente en ninguna fila.
# La palabra "Music-Based Procedural Generation" no está presente en ninguna fila.
# La palabra "Sokoban" no está presente en ninguna fila.
# La palabra "Horses" no está presente en ninguna fila.
# La palabra "Movie" no está presente en ninguna fila.
# La palabra "Nonlinear" no está presente en ninguna fila.
# La palabra "Word Game" no está presente en ninguna fila.
# La palabra "Werewolves" no está presente en ninguna fila.
# La palabra "Mining" no está presente en ninguna fila.
# La palabra "Golf" no está presente en ninguna fila.
# La palabra "Benchmark" no está presente en ninguna fila.
# La palabra "Gambling" no está presente en ninguna fila.
# La palabra "Inventory Management" no está presente en ninguna fila.
# La palabra "Gaming" no está presente en ninguna fila.
# La palabra "Lemmings" no está presente en ninguna fila.
# La palabra "Lara Croft" no está presente en ninguna fila.
# La palabra "Mystery Dungeon" no está presente en ninguna fila.
# La palabra "Experience" no está presente en ninguna fila.
# La palabra "Dynamic Narration" no está presente en ninguna fila.
# La palabra "Basketball" no está presente en ninguna fila.
# La palabra "Mini Golf" no está presente en ninguna fila.
# La palabra "Documentary" no está presente en ninguna fila.
# La palabra "Investigation" no está presente en ninguna fila.
# La palabra "Conversation" no está presente en ninguna fila.
# La palabra "Wrestling" no está presente en ninguna fila.
# La palabra "Artificial Intelligence" no está presente en ninguna fila.
# La palabra "Spelling" no está presente en ninguna fila.
# La palabra "Pool" no está presente en ninguna fila.
# La palabra "Steam Machine" no está presente en ninguna fila.
# La palabra "Intentionally Awkward Controls" no está presente en ninguna fila.
# La palabra "Underground" no está presente en ninguna fila.
# La palabra "NSFW" no está presente en ninguna fila.
# La palabra "Transhumanism" no está presente en ninguna fila.
# La palabra "Bowling" no está presente en ninguna fila.
# La palabra "Tutorial" no está presente en ninguna fila.
# La palabra "Cycling" no está presente en ninguna fila.
# La palabra "Voice Control" no está presente en ninguna fila.
# La palabra "Faith" no está presente en ninguna fila.
# La palabra "Accounting" no está presente en ninguna fila.
# La palabra "Hardware" no está presente en ninguna fila.
# La palabra "Foreign" no está presente en ninguna fila.

# %%
# Se eiliminan las comas duplicadas o que hayan quedado en posiciones incorrectas
df_games['Genres'] = df_games['Genres'].str.replace(r'^,\s*|\s*,\s*$', '', regex=True)
df_games['Genres'] = df_games['Genres'].str.replace(r'\s*,\s*,', ', ', regex=True)

# %%
# Se reemplaza las dobles comillas que puedan tener algunos géneros
df_games['Genres'] = df_games['Genres'].str.replace(r'"', '')

# %% [markdown]
# #### De esta manera se ha realizado el último proceso de transformación de datos a manera general en el Data Set.

# %% [markdown]
# ---

# %% [markdown]
# ### Primer Data Set para la función **`“PlayTimeGenre”`**

# %% [markdown]
# Gracias a un análisis previo de la consigna de la función se establecen los Data Sets y los campos necesarios solamente para esta función. En este caso los Data Sets serán **`“Items”`** y **`“Games”`** que tendrán una relación de **`“Uno”`** a **`“Muchos”`** y se relacionarán con el campo **`“Item_Id”`**, los campos que se incluirán serán **`“Items.Playtime_Forever_Hours”`**, **`“Games.Year”`** y **`“Games.Genres”`** por lo cual se hará un proceso de transformación para llegar a un nuevo Data Frame con los campos mencionados.

# %%
# Se filtra los campos que se van a usar del Data Frame Items 
def1_df_items = df_items[['Item_Id','Playtime_Forever_Hours']]
def1_df_items
# Out:
#          Item_Id  Playtime_Forever_Hours
# 0             10                       1
# 1             30                       1
# 2            300                      79
# 3            240                      31
# 4           3830                       6
# ...          ...                     ...
# 3285241   304930                      12
# 3285242   227940                       1
# 3285243   388490                       1
# 3285244   521570                       1
# 3285245   519140                       1
#
# [3285246 rows x 2 columns]

# %%
# Se filtra los campos que se van a usar del Data Frame Games
def1_df_games = df_games[['Item_Id','Year_Launch','Genres']]
def1_df_games
# Out:
#        Item_Id  Year_Launch                                             Genres
# 0       761140         2018        Simulation, Casual, Strategy, Action, Indie
# 1       643980         2018  2D, Design & Illustration, RPG,  Free to Play,...
# 2       670290         2017  Sports, Free to Play, Simulation, Casual, Mult...
# 3       767400         2017                          Adventure, Action, Casual
# 4       772540         2018  Shooter, Third Person, Simulation, Third-Perso...
# ...        ...          ...                                                ...
# 28658   745400         2018          Violent, Casual, Adventure, Action, Indie
# 28659   773640         2018                Strategy, Simulation, Casual, Indie
# 28660   733530         2018                            Strategy, Casual, Indie
# 28661   610660         2018                          Simulation, Racing, Indie
# 28662   658870         2017  Relaxing, Casual, Singleplayer, Puzzle, Indie,...
#
# [28661 rows x 3 columns]

# %%
# Se fusionan los Data Frames filtrados por la columna 'Item_Id'
merged_df = pd.merge(def1_df_items, def1_df_games, on='Item_Id', how='inner')
merged_df
# Out:
#          Item_Id  Playtime_Forever_Hours  Year_Launch  \
# 0             10                       1         2000
# 1             10                       2         2000
# 2             10                       2         2000
# 3             10                       6         2000
# 4             10                     105         2000
# ...          ...                     ...          ...
# 2797766   273800                       1         2016
# 2797767   354280                       3         2016
# 2797768   464120                       1         2016
# 2797769   367090                       1         2015
# 2797770   448540                       1         2016
#
#                                                     Genres
# 0        1990s, Team-Based, Multiplayer,  Shooter, Firs...
# 1        1990s, Team-Based, Multiplayer,  Shooter, Firs...
# 2        1990s, Team-Based, Multiplayer,  Shooter, Firs...
# 3        1990s, Team-Based, Multiplayer,  Shooter, Firs...
# 4        1990s, Team-Based, Multiplayer,  Shooter, Firs...
# ...                                                    ...
# 2797766                                         Simulation
# 2797767                  Simulation, Action, Casual, Indie
# 2797768                                          Utilities
# 2797769                              Action, Indie, Sports
# 2797770  Survival Horror, Horror,  Horror, Adventure, I...
#
# [2797771 rows x 4 columns]

# %%
# Se agrupan por 'Item_Id' y se suma 'Playtime_Forever_Hours'
df_PlayTimeGenre = merged_df.groupby('Item_Id').agg({ # (agg): Para cada grupo de 'Item_Id', calcula la suma de 'Playtime_Forever_Hours' 
    'Playtime_Forever_Hours': 'sum',                  # y toma el primer valor de 'Year_Launch' y 'Genres' (ya que son los mismos para todas las filas del grupo).
    'Year_Launch': 'first',
    'Genres': 'first'
}).reset_index() # Se resetea el Index

df_PlayTimeGenre # Se vizualiza el Data Frame
# Out:
#       Item_Id  Playtime_Forever_Hours  Year_Launch  \
# 0          10                  293487         2000
# 1          20                   17795         1999
# 2          30                   13520         2003
# 3          40                    3076         2001
# 4          50                   13288         1999
# ...       ...                     ...          ...
# 8088   527510                       4         2016
# 8089   527810                       1         2016
# 8090   527890                       1         2016
# 8091   527900                       1         2016
# 8092   528660                       4         2016
#
#                                                  Genres
# 0     1990s, Team-Based, Multiplayer,  Shooter, Firs...
# 1     1990s, Casual, Team-Based, Multiplayer, Fast-P...
# 2     Multiplayer, Shooter, War,  Historical, Co-op,...
# 3     Multiplayer, Shooter, First-Person, Sci-fi, FP...
# 4     Story Rich, Shooter, Puzzle,  Great Soundtrack...
# ...                                                 ...
# 8088                Strategy, Simulation, Casual, Indie
# 8089  Difficult, Female Protagonist, Platformer, Ret...
# 8090                                 Simulation, Casual
# 8091                   Hidden Object, Adventure, Casual
# 8092                      Puzzle, Action, Casual, Indie
#
# [8093 rows x 4 columns]

# %%
# Se visualiza en que tipo de datos estan los valores de los campos
df_PlayTimeGenre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8093 entries, 0 to 8092
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Item_Id                 8093 non-null   int64
#  1   Playtime_Forever_Hours  8093 non-null   int64
#  2   Year_Launch             8093 non-null   int64
#  3   Genres                  8093 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 253.0+ KB

# %% [markdown]
# #### Se procede a exportar el Data Frame a otros formatos para poder ser utilizados posteriormente

# %%
# Se guarda el DataFrame en formato CSV
df_PlayTimeGenre.to_csv('PlayTimeGenre.csv', index=False)

# %%
# Se convierte el archivo CSV a parquet bajo la compresión "gzip"
ruta_csv_PlayTimeGenre = 'E:\\AAADATOS\\Henry\\AA_Data_Science\\MATERIAL_PI\\PI_ML_OPS_STEAM_DSFT17\\PlayTimeGenre.csv' # Se crea una variable con la ruta del archivo CSV
df_PlayTimeGenre_temp = pd.read_csv(ruta_csv_PlayTimeGenre) # Se lee ese CSV en un nuevo DataFrame temporal para segurar como estan los datos
df_PlayTimeGenre_temp
# Out:
#       Item_Id  Playtime_Forever_Hours  Year_Launch  \
# 0          10                  293487         2000
# 1          20                   17795         1999
# 2          30                   13520         2003
# 3          40                    3076         2001
# 4          50                   13288         1999
# ...       ...                     ...          ...
# 8088   527510                       4         2016
# 8089   527810                       1         2016
# 8090   527890                       1         2016
# 8091   527900                       1         2016
# 8092   528660                       4         2016
#
#                                                  Genres
# 0     1990s, Team-Based, Multiplayer,  Shooter, Firs...
# 1     1990s, Casual, Team-Based, Multiplayer, Fast-P...
# 2     Multiplayer, Shooter, War,  Historical, Co-op,...
# 3     Multiplayer, Shooter, First-Person, Sci-fi, FP...
# 4     Story Rich, Shooter, Puzzle,  Great Soundtrack...
# ...                                                 ...
# 8088                Strategy, Simulation, Casual, Indie
# 8089  Difficult, Female Protagonist, Platformer, Ret...
# 8090                                 Simulation, Casual
# 8091                   Hidden Object, Adventure, Casual
# 8092                      Puzzle, Action, Casual, Indie
#
# [8093 rows x 4 columns]

# %%
# Se verifica el estado de sus tipos de datos 
df_PlayTimeGenre_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8093 entries, 0 to 8092
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Item_Id                 8093 non-null   int64
#  1   Playtime_Forever_Hours  8093 non-null   int64
#  2   Year_Launch             8093 non-null   int64
#  3   Genres                  8090 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 253.0+ KB

# %% [markdown]
# Se guarada el DataFrame temporal en formato comprimido gzip

# %%
df_PlayTimeGenre_temp.to_csv('PlayTimeGenre.gzip', compression='gzip', index=False)

# %%
# Se verifica que el archivo gzip comprimido pueda ser leido de manera efectiva y que no hayan problemas en los datos que este arroja
df_PlayTimeGenre_parquet = pd.read_csv('PlayTimeGenre.gzip', compression='gzip')
df_PlayTimeGenre_parquet
# Out:
#       Item_Id  Playtime_Forever_Hours  Year_Launch  \
# 0          10                  293487         2000
# 1          20                   17795         1999
# 2          30                   13520         2003
# 3          40                    3076         2001
# 4          50                   13288         1999
# ...       ...                     ...          ...
# 8088   527510                       4         2016
# 8089   527810                       1         2016
# 8090   527890                       1         2016
# 8091   527900                       1         2016
# 8092   528660                       4         2016
#
#                                                  Genres
# 0     1990s, Team-Based, Multiplayer,  Shooter, Firs...
# 1     1990s, Casual, Team-Based, Multiplayer, Fast-P...
# 2     Multiplayer, Shooter, War,  Historical, Co-op,...
# 3     Multiplayer, Shooter, First-Person, Sci-fi, FP...
# 4     Story Rich, Shooter, Puzzle,  Great Soundtrack...
# ...                                                 ...
# 8088                Strategy, Simulation, Casual, Indie
# 8089  Difficult, Female Protagonist, Platformer, Ret...
# 8090                                 Simulation, Casual
# 8091                   Hidden Object, Adventure, Casual
# 8092                      Puzzle, Action, Casual, Indie
#
# [8093 rows x 4 columns]

# %%
df_PlayTimeGenre_parquet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8093 entries, 0 to 8092
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Item_Id                 8093 non-null   int64
#  1   Playtime_Forever_Hours  8093 non-null   int64
#  2   Year_Launch             8093 non-null   int64
#  3   Genres                  8090 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 253.0+ KB

# %% [markdown]
# ---
